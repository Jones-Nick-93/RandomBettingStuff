# %%
# !pip install mplsoccer -- quiet
import re
import requests
import json
from bs4 import BeautifulSoup 
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch, Pitch
import pandas as pd
# Out:
# Requirement already satisfied: mplsoccer in c:\users\nj128\anaconda3\lib\site-packages (1.4.0)
# ERROR: Could not find a version that satisfies the requirement quiet (from versions: none)
# ERROR: No matching distribution found for quiet

# %%
base_url = 'https://understat.com/match/'
match = str(input('Please enter match id: '))
url = base_url + match
# Out:
# Please enter match id:  26757

# %%
url
# Out:
# 'https://understat.com/match/26759'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22607738\x22,\x22minute\x22\x3A\x222\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.915\x22,\x22Y\x22\x3A\x220.4929999923706055\x22,\x22xG\x22\x3A\x220.1309189647436142\x22,\x22player\x22\x3A\x22Nicolas\x20Jackson\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x2210048\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22Head\x22,\x22match_id\x22\x3A\x2226757\x22,\x22h_team\x22\x3A\x22Chelsea\x22,\x22a_team\x22\x3A\x22Brentford\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222024\x2D12\x2D15\x2019\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Malo\x20Gusto\x22,\x22lastAction\x22\x3A\x22Cross\x22\x7D,\x7B\x22id\x22\x3A\x22607739\x22,\x22minute\x22\x3A\x2210\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.9380000305175781\x22,\x22Y\x22\x3A\x220.6719999694824219\x22,\x22xG\x22\x3A\x220.05848012864589691\x22,\x22player\x22\x3A\x22Nicolas\x20Jackson\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x2210048\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222024\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2226757\x22,\x22h_team\x22\x3A\x22Chelsea\x22,\x22a_team\x22\x3A\x22Brentford\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x221\x22,\x22date\x22\x3A\x222024\x2D12\x2D15\x2019\x3A00\x3A00\x22,\x22player_assisted\x22\x3A\x22Mois\x5Cu00e9s\x20Caicedo\x22,\x22lastAction\x22\x3A\x22Chipped\x22\x7D,\x7B\x22id\x22\x3A\x22607740\x22,\x22minute\x22\x3A\x2212\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.924000015258789\x22,\x22Y\x22\x3A\x220.6730000305175782\x22,
D,\x22694595\x22\x3A\x7B\x22id\x22\x3A\x22694595\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.011494938284158707\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x229453\x22,\x22team_id\x22\x3A\x2280\x22,\x22position\x22\x3A\x22DMC\x22,\x22player\x22\x3A\x22Mois\x5Cu00e9s\x20Caicedo\x22,\x22h_a ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x224455\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22607738\\x22,\\x22minute\\x22\\x3A\\x222\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.915\\x22,\\x22Y\\x22\\x3A\\x220.4929999923706055\\x22,\\x22xG\\x22\\x3A\\x220.1309189647436142\\x22,\\x22player\\x22\\x3A\\x22Nicolas\\x20Jackson\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x2210048\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222024\\x22,\\x22shotType\\x22\\x3A\\x22Head\\x22,\\x22match_id\\x22\\x3A\\x2226757\\x22,\\x22h_team\\x22\\x3A\\x22Chelsea\\x22,\\x22a_team\\x22\\x3A\\x22Brentford\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222024\\x2D12\\x2D15\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Malo\\x20Gusto\\x22,\\x22lastAction\\x22\\x3A\\x22Cross\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22607739\\x22,\\x22minute\\x22\\x3A\\x2210\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.9380000305175781\\x22,\\x22Y\\x22\\x3A\\x220.6719999694824219\\x22,\\x22xG\\x22\\x3A\\x220.05848012864589691\\x22,\\x22player\\x22\\x3A\\x22Nicolas\\x20Jackson\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x2210048\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222024\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2226757\\x22,\\x22h_team\\x22\\x3A\\x22Chelsea\\x22,\\x22a_team\\x22\\x3A\\x22Brentford\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222024\\x2D12\\x2D15\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Mois\\x5Cu00e9s\\x20Caicedo\\x22,\\x22lastAction\\x22\\x3A\\x22Chipped\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22607740\\x22,\\x22minute\\x22\\x3A\\x2212\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.924000015258789\\x22,\\x22Y\\x22\\x3A\\x220.6730000305175782\\x22,\\x22xG\\x22\\x3A\\x220.07724382728338242\\x22,\\x22player\\x22\\x3A\\x22Cole\\x20Palmer\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x228497\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222024\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2226757\\x22,\\x22h_team\\x22\\x3A\\x22Chelsea\\x22,\\x22a_team\\x22\\x3A\\x22Brentford\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222024\\x2D12\\x2D15\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Jadon\\x20Sancho\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22607741\\x22,\\x22minute\\x22\\x3A\\x2213\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.730999984741211\\x22,\\x22Y\\x22\\x3A\\x220.3940000152587891\\x22,\\x22xG\\x22\\x3A\\x220.01732208952307701\\x22,\\x22player\\x22\\x3A\\x22Malo\\x20Gusto\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x229017\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222024\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2226757\\x22,\\x22h_team\\x22\\x3A\\x22Chelsea\\x22,\\x22a_team\\x22\\x3A\\x22Brentford\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x221\\x22,\\x22date\\x22\\x3A\\x222024\\x2D12\\x2D15\\x2019\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Mois\\x5Cu00e9s\\x20Caicedo\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22607742\\x22,\\x22minute\\x22\\x3A\\x2213\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.830999984741211\\x22,\\x22Y\\x22\\x3A\\x220.555\\x22,\\x22xG\\x22\\x3A\\x220.05137373507022858\\x22,\\x22player\\x22\\x3A\\x22Cole\\x20Palmer\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x228497\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222024\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2226757\\x22,\\x22h_team\\x22\\x3A\\x ...

# %%
ind_start = strings.index("('")+2
ind_end = strings.index("')")
json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '607738',
#    'minute': '2',
#    'result': 'MissedShots',
#    'X': '0.915',
#    'Y': '0.4929999923706055',
#    'xG': '0.1309189647436142',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Malo Gusto',
#    'lastAction': 'Cross'},
#   {'id': '607739',
#    'minute': '10',
#    'result': 'SavedShot',
#    'X': '0.9380000305175781',
#    'Y': '0.6719999694824219',
#    'xG': '0.05848012864589691',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Moisés Caicedo',
#    'lastAction': 'Chipped'},
#   {'id': '607740',
#    'minute': '12',
#    'result': 'BlockedShot',
#    'X': '0.924000015258789',
#    'Y': '0.6730000305175782',
#    'xG': '0.07724382728338242',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Jadon Sancho',
#    'lastAction': 'Pass'},
#   {'id': '607741',
#    'minute': '13',
#    'result': 'MissedShots',
#    'X': '0.730999984741211',
#    'Y': '0.3940000152587891',
#    'xG': '0.01732208952307701',
#    'player': 'Malo Gusto',
#    'h_a': 'h',
#    'player_id': '9017',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Moisés Caicedo',
#    'lastAction': 'Pass'},
#   {'id': '607742',
#    'minute': '13',
#    'result': 'SavedShot',
#    'X': '0.830999984741211',
#    'Y': '0.555',
#    'xG': '0.05137373507022858',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '607743',
#    'minute': '13',
#    'result': 'MissedShots',
#    'X': '0.905',
#    'Y': '0.3579999923706055',
#    'xG': '0.04463621601462364',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Levi Colwill',
#    'lastAction': 'Cross'},
#   {'id': '607744',
#    'minute': '19',
#    'result': 'SavedShot',
#    'X': '0.965999984741211',
#    'Y': '0.33599998474121096',
#    'xG': '0.07659464329481125',
#    'player': 'Enzo Fernández',
#    'h_a': 'h',
#    'player_id': '11356',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Noni Madueke',
#    'lastAction': 'Pass'},
#   {'id': '607745',
#    'minute': '26',
#    'result': 'BlockedShot',
#    'X': '0.8980000305175782',
#    'Y': '0.6359999847412109',
#    'xG': '0.09314537793397903',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Cole Palmer',
#    'lastAction': 'Pass'},
#   {'id': '607746',
#    'minute': '27',
#    'result': 'MissedShots',
#    'X': '0.9230000305175782',
#    'Y': '0.415',
#    'xG': '0.05515734478831291',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Enzo Fernández',
#    'lastAction': 'Cross'},
#   {'id': '607748',
#    'minute': '31',
#    'result': 'BlockedShot',
#    'X': '0.9340000152587891',
#    'Y': '0.5579999923706055',
#    'xG': '0.049143608659505844',
#    'player': 'Tosin Adarabioyo',
#    'h_a': 'h',
#    'player_id': '5590',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Cole Palmer',
#    'lastAction': 'Aerial'},
#   {'id': '607749',
#    'minute': '31',
#    'result': 'MissedShots',
#    'X': '0.960999984741211',
#    'Y': '0.6480000305175782',
#    'xG': '0.06267440319061279',
#    'player': 'Jadon Sancho',
#    'h_a': 'h',
#    'player_id': '6345',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '607750',
#    'minute': '38',
#    'result': 'SavedShot',
#    'X': '0.9259999847412109',
#    'Y': '0.325',
#    'xG': '0.31095972657203674',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'BallRecovery'},
#   {'id': '607751',
#    'minute': '42',
#    'result': 'Goal',
#    'X': '0.9259999847412109',
#    'Y': '0.5320000076293945',
#    'xG': '0.34663426876068115',
#    'player': 'Marc Cucurella',
#    'h_a': 'h',
#    'player_id': '7134',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Noni Madueke',
#    'lastAction': 'Cross'},
#   {'id': '607752',
#    'minute': '44',
#    'result': 'BlockedShot',
#    'X': '0.749000015258789',
#    'Y': '0.5359999847412109',
#    'xG': '0.027692707255482674',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Enzo Fernández',
#    'lastAction': 'Pass'},
#   {'id': '607753',
#    'minute': '44',
#    'result': 'MissedShots',
#    'X': '0.835999984741211',
#    'Y': '0.4520000076293945',
#    'xG': '0.03532357141375542',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '607754',
#    'minute': '47',
#    'result': 'MissedShots',
#    'X': '0.8340000152587891',
#    'Y': '0.35200000762939454',
#    'xG': '0.03408107906579971',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Malo Gusto',
#    'lastAction': 'Pass'},
#   {'id': '607755',
#    'minute': '58',
#    'result': 'BlockedShot',
#    'X': '0.8330000305175781',
#    'Y': '0.515',
#    'xG': '0.11921712756156921',
#    'player': 'Enzo Fernández',
#    'h_a': 'h',
#    'player_id': '11356',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Cole Palmer',
#    'lastAction': 'Pass'},
#   {'id': '607756',
#    'minute': '59',
#    'result': 'MissedShots',
#    'X': '0.9369999694824219',
#    'Y': '0.44599998474121094',
#    'xG': '0.5477221012115479',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Jadon Sancho',
#    'lastAction': 'Pass'},
#   {'id': '607758',
#    'minute': '65',
#    'result': 'SavedShot',
#    'X': '0.730999984741211',
#    'Y': '0.45',
#    'xG': '0.04398573935031891',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '607759',
#    'minute': '67',
#    'result': 'BlockedShot',
#    'X': '0.9330000305175781',
#    'Y': '0.34799999237060547',
#    'xG': '0.08621402084827423',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '607762',
#    'minute': '74',
#    'result': 'MissedShots',
#    'X': '0.7709999847412109',
#    'Y': '0.6279999923706054',
#    'xG': '0.03176857531070709',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Jadon Sancho',
#    'lastAction': 'Pass'},
#   {'id': '607766',
#    'minute': '79',
#    'result': 'Goal',
#    'X': '0.8530000305175781',
#    'Y': '0.375',
#    'xG': '0.09284038096666336',
#    'player': 'Nicolas Jackson',
#    'h_a': 'h',
#    'player_id': '10048',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Enzo Fernández',
#    'lastAction': 'Pass'},
#   {'id': '607768',
#    'minute': '86',
#    'result': 'MissedShots',
#    'X': '0.8680000305175781',
#    'Y': '0.5170000076293946',
#    'xG': '0.03937623277306557',
#    'player': 'Tosin Adarabioyo',
#    'h_a': 'h',
#    'player_id': '5590',
#    'situation': 'SetPiece',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Cole Palmer',
#    'lastAction': 'Cross'},
#   {'id': '607769',
#    'minute': '86',
#    'result': 'SavedShot',
#    'X': '0.7380000305175781',
#    'Y': '0.8280000305175781',
#    'xG': '0.011494938284158707',
#    'player': 'Moisés Caicedo',
#    'h_a': 'h',
#    'player_id': '9453',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'BallRecovery'},
#   {'id': '607770',
#    'minute': '86',
#    'result': 'BlockedShot',
#    'X': '0.88',
#    'Y': '0.3559999847412109',
#    'xG': '0.07850421965122223',
#    'player': 'Noni Madueke',
#    'h_a': 'h',
#    'player_id': '11357',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Marc Cucurella',
#    'lastAction': 'BallRecovery'},
#   {'id': '607772',
#    'minute': '91',
#    'result': 'BlockedShot',
#    'X': '0.8119999694824219',
#    'Y': '0.649000015258789',
#    'xG': '0.07292923331260681',
#    'player': 'Cole Palmer',
#    'h_a': 'h',
#    'player_id': '8497',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Jadon Sancho',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '607747',
#    'minute': '28',
#    'result': 'BlockedShot',
#    'X': '0.8959999847412109',
#    'Y': '0.4520000076293945',
#    'xG': '0.1277959644794464',
#    'player': 'Mikkel Damsgaard',
#    'h_a': 'a',
#    'player_id': '8859',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Mads Roerslev',
#    'lastAction': 'Pass'},
#   {'id': '607757',
#    'minute': '62',
#    'result': 'BlockedShot',
#    'X': '0.9109999847412109',
#    'Y': '0.5329999923706055',
#    'xG': '0.035672951489686966',
#    'player': 'Vitaly Janelt',
#    'h_a': 'a',
#    'player_id': '9680',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'Head',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Mads Roerslev',
#    'lastAction': 'Aerial'},
#   {'id': '607760',
#    'minute': '72',
#    'result': 'MissedShots',
#    'X': '0.915',
#    'Y': '0.6359999847412109',
#    'xG': '0.04419904202222824',
#    'player': 'Christian Nørgaard',
#    'h_a': 'a',
#    'player_id': '7083',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Bryan Mbeumo',
#    'lastAction': 'Cross'},
#   {'id': '607761',
#    'minute': '72',
#    'result': 'SavedShot',
#    'X': '0.914000015258789',
#    'Y': '0.5579999923706055',
#    'xG': '0.3159642517566681',
#    'player': 'Christian Nørgaard',
#    'h_a': 'a',
#    'player_id': '7083',
#    'situation': 'FromCorner',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Nathan Collins',
#    'lastAction': 'Cross'},
#   {'id': '607763',
#    'minute': '75',
#    'result': 'ShotOnPost',
#    'X': '0.945',
#    'Y': '0.47400001525878904',
#    'xG': '0.4976228177547455',
#    'player': 'Fabio Carvalho',
#    'h_a': 'a',
#    'player_id': '9501',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Kristoffer Ajer',
#    'lastAction': 'Cross'},
#   {'id': '607764',
#    'minute': '75',
#    'result': 'MissedShots',
#    'X': '0.9790000152587891',
#    'Y': '0.605',
#    'xG': '0.07716888189315796',
#    'player': 'Kevin Schade',
#    'h_a': 'a',
#    'player_id': '9156',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '607765',
#    'minute': '77',
#    'result': 'SavedShot',
#    'X': '0.759000015258789',
#    'Y': '0.695',
#    'xG': '0.013769912533462048',
#    'player': 'Keane Lewis-Potter',
#    'h_a': 'a',
#    'player_id': '10809',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': None,
#    'lastAction': 'TakeOn'},
#   {'id': '607767',
#    'minute': '84',
#    'result': 'SavedShot',
#    'X': '0.9519999694824218',
#    'Y': '0.425',
#    'xG': '0.39931848645210266',
#    'player': 'Bryan Mbeumo',
#    'h_a': 'a',
#    'player_id': '6552',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'RightFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Vitaly Janelt',
#    'lastAction': 'Throughball'},
#   {'id': '607771',
#    'minute': '89',
#    'result': 'Goal',
#    'X': '0.7969999694824219',
#    'Y': '0.37099998474121093',
#    'xG': '0.18549636006355286',
#    'player': 'Bryan Mbeumo',
#    'h_a': 'a',
#    'player_id': '6552',
#    'situation': 'OpenPlay',
#    'season': '2024',
#    'shotType': 'LeftFoot',
#    'match_id': '26757',
#    'h_team': 'Chelsea',
#    'a_team': 'Brentford',
#    'h_goals': '2',
#    'a_goals': '1',
#    'date': '2024-12-15 19:00:00',
#    'player_assisted': 'Kevin Schade',
#    'lastAction': 'TakeOn'}]}

# %%
x = []
y = []
xg = []
result = []
player = []
team = []
data_away = data['a']
data_home = data['h']

# %%
for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'xG':
            xg.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'xG':
            xg.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])

# %%
col_names = ['x','y','xg','result','player','team']
shot_df = pd.DataFrame([x,y,xg,result,player,team],index=col_names)

# %%
df = shot_df.T

# %%
df
# Out:
#                      x                    y                    xg  \
# 0                0.915   0.4929999923706055    0.1309189647436142
# 1   0.9380000305175781   0.6719999694824219   0.05848012864589691
# 2    0.924000015258789   0.6730000305175782   0.07724382728338242
# 3    0.730999984741211   0.3940000152587891   0.01732208952307701
# 4    0.830999984741211                0.555   0.05137373507022858
# 5                0.905   0.3579999923706055   0.04463621601462364
# 6    0.965999984741211  0.33599998474121096   0.07659464329481125
# 7   0.8980000305175782   0.6359999847412109   0.09314537793397903
# 8   0.9230000305175782                0.415   0.05515734478831291
# 9   0.9340000152587891   0.5579999923706055  0.049143608659505844
# 10   0.960999984741211   0.6480000305175782   0.06267440319061279
# 11  0.9259999847412109                0.325   0.31095972657203674
# 12  0.9259999847412109   0.5320000076293945   0.34663426876068115
# 13   0.749000015258789   0.5359999847412109  0.027692707255482674
# 14   0.835999984741211   0.4520000076293945   0.03532357141375542
# 15  0.8340000152587891  0.35200000762939454   0.03408107906579971
# 16  0.8330000305175781                0.515   0.11921712756156921
# 17  0.9369999694824219  0.44599998474121094    0.5477221012115479
# 18   0.730999984741211                 0.45   0.04398573935031891
# 19  0.9330000305175781  0.34799999237060547   0.08621402084827423
# 20  0.7709999847412109   0.6279999923706054   0.03176857531070709
# 21  0.8530000305175781                0.375   0.09284038096666336
# 29    SavedShot  Christian Nørgaard  Brentford
# 30   ShotOnPost      Fabio Carvalho  Brentford
# 31  MissedShots        Kevin Schade  Brentford
# 32    SavedShot  Keane Lewis-Potter  Brentford
# 33    SavedShot        Bryan Mbeumo  Brentford
# 34         Goal        Bryan Mbeumo  Brentford

# %%
df.dtypes
# Out:
# x         object
# y         object
# xg        object
# result    object
# player    object
# team      object
# dtype: object

# %%
df.to_csv (r'C:\Users\nj128\OneDrive\Documents\chelsea_brentford_shots_12_15.csv', index = None, header=True)

# %%
total_shots = df.shape[0]
total_goals = df[df['result'] == 'Goal'].shape[0]
df['xg'] = pd.to_numeric(df['xg'], errors ='coerce')
total_xG = df['xg'].sum()
df['x'] = pd.to_numeric(df['x'],errors = 'coerce')
points_average_distance = df['x'].mean()
actual_average_distance = 120 - (df['x'] * 1.2).mean()

print(f"Total Shots: {total_shots}")
print(f"Total Goals: {total_goals}")
print(f"Total xG: {total_xG:.2f}")
print(f"Points Average Distance: {points_average_distance:.2f}")
print(f"Actual Average Distance: {actual_average_distance:.2f}")
# Out:
# Total Shots: 35
# Total Goals: 3
# Total xG: 4.29
# Points Average Distance: 0.87
# Actual Average Distance: 118.95

# %%
shot_data = df

# %% [markdown]
# NEW DYNAMIC TEAM TEXT VIZ

# %%
# Ensure required columns exist and are numeric
required_columns = {'team', 'result', 'x', 'y', 'xg'}
if not required_columns.issubset(shot_data.columns):
    raise ValueError(f"shot_data is missing one or more required columns: {required_columns}")

# Convert necessary columns to numeric
for col in ['x', 'y', 'xg']:
    shot_data[col] = pd.to_numeric(shot_data[col], errors='coerce')

# Drop rows with invalid numeric values
shot_data.dropna(subset=['x', 'y', 'xg'], inplace=True)

# Get the unique team names (assume first team is home and second is away)
unique_teams = shot_data['team'].unique()
if len(unique_teams) != 2:
    raise ValueError("Expected exactly two unique teams in the 'team' column.")

home_team, away_team = unique_teams

# Define team colors (unique for each team)
team_colors = {
    home_team: '#034694',  #  Home Team
    away_team: '#8D021F'   # Orange for Away Team
}

# Define markers for each shot result
result_markers = {
    'Goal': '*',           # Circle
    'BlockedShot': 'x',    # Cross
    'SavedShot': '+',      # Square
    'MissedShots': '^'     # Triangle
}

# Split the data by team
team_data = {team: shot_data[shot_data['team'] == team] for team in unique_teams}

# Create the figure with two half-pitches
fig, axs = plt.subplots(1, 2, figsize=(16, 9))
pitch = VerticalPitch(pitch_color='white', line_color='black', half=True)

# Plot each half of the pitch
for i, ax in enumerate(axs):
    pitch.draw(ax=ax)  # Draw pitch on each axis

    # Determine team and flip y-axis for away team
    team = home_team if i == 0 else away_team
    data = team_data[team]

    for result, marker in result_markers.items():
        result_data = data[data['result'] == result]
        if not result_data.empty:
            pitch.scatter(
                result_data['x'] * 120,  # Scale x-coordinates
                result_data['y'] * 80 if i == 0 else 80 - result_data['y'] * 80,  # Flip y for away team
                s=result_data['xg'] * 1000,  # Marker size proportional to xG
                color=team_colors[team], marker=marker, alpha=0.7,
                label=f"{team} - {result}" if i == 0 else "", ax=ax
            )
            # Annotate xG values
            for _, row in result_data.iterrows():
                ax.text(
                    row['x'] * 120,
                    row['y'] * 80 if i == 0 else 80 - row['y'] * 80,
                    f"{row['xg']:.2f}",
                    color='black', ha='center', va='center', fontsize=8
                )
    # Add team-specific text for xG summary
    total_xg = data['xg'].sum()
    total_shots = data.shape[0]
    ax.text(
        10, 75,  # Position for text
        f"{team}\nTotal xG: {total_xg:.2f}\nShots: {total_shots}",
        fontsize=12, color=team_colors[team], ha='left', va='center'
    )

# Add a shared title
fig.suptitle(f'Shot Map: {home_team} vs. {away_team}', fontsize=16)

# Add legend
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=4, frameon=False, fontsize=10)

plt.tight_layout()
plt.show()

# %%
from mplsoccer import VerticalPitch
import matplotlib.pyplot as plt
import pandas as pd

# Ensure required columns exist and are numeric
required_columns = {'team', 'result', 'x', 'y', 'xg', 'player'}
if not required_columns.issubset(shot_data.columns):
    raise ValueError(f"shot_data is missing one or more required columns: {required_columns}")

# Convert necessary columns to numeric
for col in ['x', 'y', 'xg']:
    shot_data[col] = pd.to_numeric(shot_data[col], errors='coerce')

# Drop rows with invalid numeric values
shot_data.dropna(subset=['x', 'y', 'xg'], inplace=True)

# Get the unique team names (assume first team is home and second is away)
unique_teams = shot_data['team'].unique()
if len(unique_teams) != 2:
    raise ValueError("Expected exactly two unique teams in the 'team' column.")

home_team, away_team = unique_teams

# Define team colors (unique for each team)
team_colors = {
    home_team: '#034694',  # Blue for Home Team
    away_team: '#8D021F'   # Dark Red for Away Team
}

# Define markers for each shot result
result_markers = {
    'Goal': '*',           # Star
    'BlockedShot': 'x',    # Cross
    'SavedShot': '+',      # Plus
    'MissedShots': '^'     # Triangle
}

# Split the data by team
team_data = {team: shot_data[shot_data['team'] == team] for team in unique_teams}

# Create the figure with two half-pitches
fig, axs = plt.subplots(1, 2, figsize=(16, 9))
pitch = VerticalPitch(pitch_color='white', line_color='black', half=True)

# Plot each half of the pitch
for i, ax in enumerate(axs):
    pitch.draw(ax=ax)  # Draw pitch on each axis

    # Determine team and flip y-axis for away team
    team = home_team if i == 0 else away_team
    data = team_data[team]

    for result, marker in result_markers.items():
        result_data = data[data['result'] == result]
        if not result_data.empty:
            pitch.scatter(
                result_data['x'] * 120,  # Scale x-coordinates
                result_data['y'] * 80 if i == 0 else 80 - result_data['y'] * 80,  # Flip y for away team
                s=result_data['xg'] * 1000,  # Marker size proportional to xG
                color=team_colors[team], marker=marker, alpha=0.7,
                label=f"{team} - {result}" if i == 0 else "", ax=ax
            )
            # Annotate xG values and player names above the markers
            for _, row in result_data.iterrows():
                ax.text(
                    row['x'] * 120,  # x-coordinate
                    (row['y'] * 80 if i == 0 else 80 - row['y'] * 80) + 2,  # y-coordinate slightly above
                    f"{row['player']}\n{row['xg']:.2f}",  # Combine player name and xG
                    color='black', ha='center', va='bottom', fontsize=8, fontweight='bold'
                )

    # Add team-specific text for xG summary
    total_xg = data['xg'].sum()
    total_shots = data.shape[0]
    ax.text(
        10, 75,  # Position for text
        f"{team}\nTotal xG: {total_xg:.2f}\nShots: {total_shots}",
        fontsize=12, color=team_colors[team], ha='left', va='center'
    )

# Add a shared title
fig.suptitle(f'Shot Map: {home_team} vs. {away_team}', fontsize=16)

# Add legend
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=4, frameon=False, fontsize=10)

plt.tight_layout()
plt.show()

# %%
from mplsoccer import VerticalPitch
import matplotlib.pyplot as plt
import pandas as pd

# Ensure required columns exist and are numeric
required_columns = {'team', 'result', 'x', 'y', 'xg', 'player'}
if not required_columns.issubset(shot_data.columns):
    raise ValueError(f"shot_data is missing one or more required columns: {required_columns}")

# Convert necessary columns to numeric
for col in ['x', 'y', 'xg']:
    shot_data[col] = pd.to_numeric(shot_data[col], errors='coerce')

# Drop rows with invalid numeric values
shot_data.dropna(subset=['x', 'y', 'xg'], inplace=True)

# Get the unique team names (assume first team is home and second is away)
unique_teams = shot_data['team'].unique()
if len(unique_teams) != 2:
    raise ValueError("Expected exactly two unique teams in the 'team' column.")

home_team, away_team = unique_teams

# Define team colors (unique for each team)
team_colors = {
    home_team: '#034694',  # Blue for Home Team
    away_team: '#8D021F'   # Dark Red for Away Team
}

# Define markers for each shot result
result_markers = {
    'Goal': '*',           # Star
    'BlockedShot': 'x',    # Cross
    'SavedShot': '+',      # Plus
    'MissedShots': '^'     # Triangle
}

# Split the data by team
team_data = {team: shot_data[shot_data['team'] == team] for team in unique_teams}

# Create the figure with two half-pitches
fig, axs = plt.subplots(1, 2, figsize=(16, 9))
pitch = VerticalPitch(pitch_color='white', line_color='black', half=True)

# Prepare player shot summaries
summary_texts = {}
for team in unique_teams:
    team_shots = team_data[team]
    # Create a summary of player names and their xG values
    summary = "\n".join([
        f"{row['player']}: {row['result']}:{row['xg']:.2f}xG" for _, row in team_shots.iterrows()
    ])
    total_xg = team_shots['xg'].sum()
    total_shots = team_shots.shape[0]
    summary_texts[team] = f"{team}\nTotal xG: {total_xg:.2f}\nShots: {total_shots}\n\n{summary}"

# Plot each half of the pitch
for i, ax in enumerate(axs):
    pitch.draw(ax=ax)  # Draw pitch on each axis

    # Determine team and flip y-axis for away team
    team = home_team if i == 0 else away_team
    data = team_data[team]

    for result, marker in result_markers.items():
        result_data = data[data['result'] == result]
        if not result_data.empty:
            pitch.scatter(
                result_data['x'] * 120,  # Scale x-coordinates
                result_data['y'] * 80 if i == 0 else 80 - result_data['y'] * 80,  # Flip y for away team
                s=result_data['xg'] * 1000,  # Marker size proportional to xG
                color=team_colors[team], marker=marker, alpha=0.7,
                label=f"{team} - {result}" if i == 0 else "", ax=ax
            )
 #   total_xg = data['xg'].sum()
 #   total_shots = data.shape[0]
 #   ax.text(
 #       10, 75,  # Position for text
 #       f"{team}\nTotal xG: {total_xg:.2f}\nShots: {total_shots}",
 #       fontsize=12, color=team_colors[team], ha='left', va='center'
 #   )



# Add a shared title
fig.suptitle(f'Shot Map: {home_team} vs. {away_team}', fontsize=16)

# Add player summaries above the pitches
fig.text(0.25, 0.95, summary_texts[home_team], ha='center', va='top', fontsize=10, color=team_colors[home_team])
fig.text(0.75, 0.95, summary_texts[away_team], ha='center', va='top', fontsize=10, color=team_colors[away_team])

# Add legend
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=4, frameon=False, fontsize=10)

plt.tight_layout(rect=[0, 0, 1, 0.9])  # Adjust layout to fit the text above the pitches
plt.show()
